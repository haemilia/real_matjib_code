# %% [markdown]
# - 연남동 필터링 : 주소지에 '연남동' 포함된 행
# - 우편번호 + 사업장명(가게명) 열 생성하여 해당 데이터로 구글maps 검색

# %%
import pandas as pd
import requests
import time
from tqdm import tqdm

# Google API 키
API_KEY =

# %%
# 1단계: csv 파일 불러오기
df = pd.read_csv("C:/medici_class/00.프로젝트/최종프로젝트 임시파일/마포구_음식점.csv", dtype={"도로명우편번호": str}, encoding='cp949')
df.head()
# Out:
#    번호 개방서비스명    개방서비스아이디  개방자치단체코드                    관리번호       인허가일자  \
# 0   1  일반음식점  07_24_04_P   3130000  3130000-101-2025-00327  2025-05-14
# 1   2  일반음식점  07_24_04_P   3130000  3130000-101-2025-00326  2025-05-14
# 2   3  일반음식점  07_24_04_P   3130000  3130000-101-2025-00322  2025-05-13
# 3   4  일반음식점  07_24_04_P   3130000  3130000-101-2025-00323  2025-05-13
# 4   5  일반음식점  07_24_04_P   3130000  3130000-101-2025-00325  2025-05-13
#
#    인허가취소일자  영업상태구분코드  영업상태명  상세영업상태코드  ... 공장판매직직원수  공장생산직직원수  건물소유구분명  보증액  \
# 0      NaN         1  영업/정상         1  ...      0.0       0.0      NaN  0.0
# 1      NaN         1  영업/정상         1  ...      0.0       0.0      NaN  0.0
# 2      NaN         1  영업/정상         1  ...      0.0       0.0      NaN  0.0
# 3      NaN         1  영업/정상         1  ...      0.0       0.0      NaN  0.0
# 4      NaN         1  영업/정상         1  ...      0.0       0.0      NaN  0.0
#
#    월세액 다중이용업소여부  시설총규모 전통업소지정번호 전통업소주된음식 홈페이지
# 0  0.0        N  54.75      NaN      NaN  NaN
# 1  0.0        N  62.04      NaN      NaN  NaN
# 2  0.0        N  74.41      NaN      NaN  NaN
# 3  0.0        N  65.00      NaN      NaN  NaN
# 4  0.0        N  82.80      NaN      NaN  NaN
#
# [5 rows x 47 columns]

# %%
# 주소지가 적힌 열 2개
address_columns = ['소재지전체주소', '도로명전체주소']

# 연남동이 포함된 행 필터링
mask = df[address_columns[0]].astype(str).str.contains("연남동") | df[address_columns[1]].astype(str).str.contains("연남동")
df_yeonnam = df[mask].copy()
df_yeonnam
# Out:
#         번호 개방서비스명    개방서비스아이디  개방자치단체코드                    관리번호       인허가일자  \
# 2        3  일반음식점  07_24_04_P   3130000  3130000-101-2025-00322  2025-05-13
# 15      16  일반음식점  07_24_04_P   3130000  3130000-101-2025-00313  2025-05-12
# 16      17  일반음식점  07_24_04_P   3130000  3130000-101-2025-00299  2025-05-09
# 20      21  일반음식점  07_24_04_P   3130000  3130000-101-2025-00298  2025-05-09
# 47      48  일반음식점  07_24_04_P   3130000  3130000-101-2025-00282  2025-05-07
# ...    ...    ...         ...       ...                     ...         ...
# 8056  8057  일반음식점  07_24_04_P   3130000  3130000-101-1992-05215  1992-03-01
# 8081  8082  일반음식점  07_24_04_P   3130000  3130000-101-1990-01963  1990-11-21
# 8121  8122  일반음식점  07_24_04_P   3130000  3130000-101-1987-02386  1987-05-09
# 8136  8137  일반음식점  07_24_04_P   3130000  3130000-101-1985-05216  1985-09-21
# 8148  8149  일반음식점  07_24_04_P   3130000  3130000-101-1984-01944  1984-12-20
#
#       인허가취소일자  영업상태구분코드  영업상태명  상세영업상태코드  ... 공장판매직직원수  공장생산직직원수  건물소유구분명  \
# 2         NaN         1  영업/정상         1  ...      0.0       0.0      NaN
# 15        NaN         1  영업/정상         1  ...      0.0       0.0      NaN
# 16        NaN         1  영업/정상         1  ...      0.0       0.0      NaN
# 20        NaN         1  영업/정상         1  ...      0.0       0.0      NaN
# 47        NaN         1  영업/정상         1  ...      0.0       0.0      NaN
# ...       ...       ...    ...       ...  ...      ...       ...      ...
# 8056      NaN         1  영업/정상         1  ...      NaN       NaN      NaN
# 8081      NaN         1  영업/정상         1  ...      0.0       0.0      NaN
# 8121      NaN         1  영업/정상         1  ...      0.0       0.0      NaN
# 8136      NaN         1  영업/정상         1  ...      NaN       NaN      NaN
# 8148      NaN         1  영업/정상         1  ...      NaN       NaN      NaN
#
#       보증액  월세액 다중이용업소여부  시설총규모 전통업소지정번호 전통업소주된음식 홈페이지
# 2     0.0  0.0        N  74.41      NaN      NaN  NaN
# 15    0.0  0.0        N  50.37      NaN      NaN  NaN
# 16    0.0  0.0        N  73.17      NaN      NaN  NaN
# 20    0.0  0.0        N  45.35      NaN      NaN  NaN
# 47    0.0  0.0        N  35.80      NaN      NaN  NaN
# ...   ...  ...      ...    ...      ...      ...  ...
# 8056  NaN  NaN        N  24.32      NaN      NaN  NaN
# 8081  0.0  0.0        N  36.73      NaN      NaN  NaN
# 8121  0.0  0.0        N  31.91      NaN      NaN  NaN
# 8136  NaN  NaN        N  61.91      NaN      NaN  NaN
# 8148  NaN  NaN        N  35.60      NaN      NaN  NaN
#
# [807 rows x 47 columns]

# %%
df_yeonnam.columns
# Out:
# Index(['번호', '개방서비스명', '개방서비스아이디', '개방자치단체코드', '관리번호', '인허가일자', '인허가취소일자',
#        '영업상태구분코드', '영업상태명', '상세영업상태코드', '상세영업상태명', '폐업일자', '휴업시작일자', '휴업종료일자',
#        '재개업일자', '소재지전화', '소재지면적', '소재지우편번호', '소재지전체주소', '도로명전체주소', '도로명우편번호',
#        '사업장명', '최종수정시점', '데이터갱신구분', '데이터갱신일자', '업태구분명', '좌표정보X(EPSG5174)',
#        '좌표정보Y(EPSG5174)', '위생업태명', '남성종사자수', '여성종사자수', '영업장주변구분명', '등급구분명',
#        '급수시설구분명', '총직원수', '본사직원수', '공장사무직직원수', '공장판매직직원수', '공장생산직직원수',
#        '건물소유구분명', '보증액', '월세액', '다중이용업소여부', '시설총규모', '전통업소지정번호', '전통업소주된음식',
#        '홈페이지'],
#       dtype='object')

# %%
# 불필요한 열 삭제
df_yeonnam = df_yeonnam.drop(['번호', '개방서비스명', '개방서비스아이디', '개방자치단체코드', '관리번호', '인허가일자', '인허가취소일자',
       '영업상태구분코드', '영업상태명', '상세영업상태코드', '상세영업상태명', '폐업일자', '휴업시작일자', '휴업종료일자',
       '재개업일자', '소재지전화', '소재지면적', '소재지우편번호', '최종수정시점', '데이터갱신구분', '데이터갱신일자', '업태구분명', '좌표정보X(EPSG5174)',
       '좌표정보Y(EPSG5174)', '위생업태명', '남성종사자수', '여성종사자수', '영업장주변구분명', '등급구분명',
       '급수시설구분명', '총직원수', '본사직원수', '공장사무직직원수', '공장판매직직원수', '공장생산직직원수',
       '건물소유구분명', '보증액', '월세액', '다중이용업소여부', '시설총규모', '전통업소지정번호', '전통업소주된음식',
       '홈페이지'], axis=1)
df_yeonnam
# Out:
#                          소재지전체주소                                도로명전체주소  \
# 2         서울특별시 마포구 연남동 383-100            서울특별시 마포구 연희로1길 63, 2층 (연남동)
# 15         서울특별시 마포구 연남동 390-71          서울특별시 마포구 동교로38길 13, 지1층 (연남동)
# 16         서울특별시 마포구 연남동 373-12               서울특별시 마포구 연남로 8, 1층 (연남동)
# 20         서울특별시 마포구 연남동 373-12               서울특별시 마포구 연남로 8, 지층 (연남동)
# 47         서울특별시 마포구 연남동 390-28   서울특별시 마포구 동교로38길 27-19, 지층 B02호 (연남동)
# ...                          ...                                    ...
# 8056        서울특별시 마포구 연남동 228-5            서울특별시 마포구 성미산로 186 (연남동, 1층)
# 8081    서울특별시 마포구 연남동 260-28 1층              서울특별시 마포구 동교로 240 (연남동,1층)
# 8121  서울특별시 마포구 연남동 568-23 (1층)          서울특별시 마포구 동교로27길 41 (연남동,(1층))
# 8136        서울특별시 마포구 연남동 228-1            서울특별시 마포구 성미산로 190 (연남동, 1층)
# 8148   서울특별시 마포구 연남동 227-1번지 1층               서울특별시 마포구 연희로 35 (연남동,1층)
#
#      도로명우편번호       사업장명
# 2      03982        사르르
# 15     03982  빨강꼬치&꼬떡상회
# 16     03989        지라파
# 20     03989        지라파
# 47     03982        돈토키
# ...      ...        ...
# 8056   03982       연남제비
# 8081   03982   유키모찌 연남점
# 8121   03991   항저우 샤롱바오
# 8136   03982     뭉텅 연남점
# 8148   03982        코리아
#
# [807 rows x 4 columns]

# %%
df_yeonnam.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 807 entries, 2 to 8148
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   소재지전체주소  804 non-null    object
#  1   도로명전체주소  807 non-null    object
#  2   도로명우편번호  806 non-null    object
#  3   사업장명     807 non-null    object
# dtypes: object(4)
# memory usage: 31.5+ KB

# %%
# 우편번호 + 가게명 조합 열 생성
df_yeonnam["검색어"] = df_yeonnam["도로명우편번호"] + " " + df_yeonnam["사업장명"]
df_yeonnam
# Out:
#                          소재지전체주소                                도로명전체주소  \
# 2         서울특별시 마포구 연남동 383-100            서울특별시 마포구 연희로1길 63, 2층 (연남동)
# 15         서울특별시 마포구 연남동 390-71          서울특별시 마포구 동교로38길 13, 지1층 (연남동)
# 16         서울특별시 마포구 연남동 373-12               서울특별시 마포구 연남로 8, 1층 (연남동)
# 20         서울특별시 마포구 연남동 373-12               서울특별시 마포구 연남로 8, 지층 (연남동)
# 47         서울특별시 마포구 연남동 390-28   서울특별시 마포구 동교로38길 27-19, 지층 B02호 (연남동)
# ...                          ...                                    ...
# 8056        서울특별시 마포구 연남동 228-5            서울특별시 마포구 성미산로 186 (연남동, 1층)
# 8081    서울특별시 마포구 연남동 260-28 1층              서울특별시 마포구 동교로 240 (연남동,1층)
# 8121  서울특별시 마포구 연남동 568-23 (1층)          서울특별시 마포구 동교로27길 41 (연남동,(1층))
# 8136        서울특별시 마포구 연남동 228-1            서울특별시 마포구 성미산로 190 (연남동, 1층)
# 8148   서울특별시 마포구 연남동 227-1번지 1층               서울특별시 마포구 연희로 35 (연남동,1층)
#
#      도로명우편번호       사업장명              검색어
# 2      03982        사르르        03982 사르르
# 15     03982  빨강꼬치&꼬떡상회  03982 빨강꼬치&꼬떡상회
# 16     03989        지라파        03989 지라파
# 20     03989        지라파        03989 지라파
# 47     03982        돈토키        03982 돈토키
# ...      ...        ...              ...
# 8056   03982       연남제비       03982 연남제비
# 8081   03982   유키모찌 연남점   03982 유키모찌 연남점
# 8121   03991   항저우 샤롱바오   03991 항저우 샤롱바오
# 8136   03982     뭉텅 연남점     03982 뭉텅 연남점
# 8148   03982        코리아        03982 코리아
#
# [807 rows x 5 columns]

# %%
# Google Maps API 요청 함수
def get_place_id(query):
    """검색어로 place_id 얻기"""
    url = "https://maps.googleapis.com/maps/api/place/findplacefromtext/json"
    params = {
        "input": query,
        "inputtype": "textquery",
        "fields": "place_id,name",
        "key": API_KEY
    }
    res = requests.get(url, params=params).json()
    candidates = res.get("candidates")
    if candidates:
        return candidates[0]["place_id"], candidates[0]["name"]
    return None, None

def get_reviews(place_id):
    """place_id로부터 평점과 리뷰내용 가져오기"""
    url = "https://maps.googleapis.com/maps/api/place/details/json"
    params = {
        "place_id": place_id,
        "fields": "review",
        "key": API_KEY,
        "language": "ko"
    }
    res = requests.get(url, params=params).json()
    reviews = res.get("result", {}).get("reviews", [])
    result = []
    for r in reviews:
        result.append({
            "별점": r.get("rating"),
            "리뷰내용": r.get("text"),
            "작성자": r.get("author_name"),
            "작성자 프로필 링크":r.get("author_url"),
            "시간": r.get("relative_time_description")
        })
    return result

# 리뷰 수집
all_reviews = []
for i, row in tqdm(df_yeonnam.iterrows(), total=len(df_yeonnam)):
    search_query = row["검색어"]
    store_name = row["사업장명"]
    
    try:
        place_id, place_name = get_place_id(search_query)
        if place_id:
            reviews = get_reviews(place_id)
            for review in reviews:
                review["사업장명"] = store_name
                review["검색결과 가게명"] = place_name
                all_reviews.append(review)
        else:
            print(f"[미발견] {search_query}")
        time.sleep(0.3)  # 너무 빠른 요청 방지
    except Exception as e:
        print(f"[오류] {search_query}: {e}")
        continue

# 결과 저장
df_reviews = pd.DataFrame(all_reviews)
df_reviews.to_csv("yeonnam_restaurant_reviews_googlemaps.csv", index=False, encoding="utf-8-sig")
print("리뷰 수집 완료 및 저장 완료")
# Out:
#   0%|          | 1/807 [00:00<12:36,  1.07it/s]
# [미발견] 03982 빨강꼬치&꼬떡상회
#   0%|          | 2/807 [00:01<10:05,  1.33it/s]
# [미발견] 03989 지라파
#   0%|          | 3/807 [00:02<09:23,  1.43it/s]
# [미발견] 03989 지라파
#   1%|          | 5/807 [00:03<10:00,  1.34it/s]
# [미발견] 03980 에스유 치즈카페
#   1%|          | 8/807 [00:06<11:20,  1.17it/s]
# [미발견] 03985 라디오 시티
#   1%|▏         | 12/807 [00:09<12:11,  1.09it/s]
# [미발견] 03982 주실
#   2%|▏         | 13/807 [00:10<11:12,  1.18it/s]
# [미발견] 03982 리플리
#   2%|▏         | 14/807 [00:11<10:30,  1.26it/s]
# [미발견] 03982 홍콩데이
#   2%|▏         | 15/807 [00:11<09:45,  1.35it/s]
# [미발견] 03982 연남잿불
#   2%|▏         | 20/807 [00:16<11:54,  1.10it/s]
# [미발견] 03982 윅스(weXX)
#   4%|▍         | 34/807 [00:29<12:00,  1.07it/s]
# [미발견] 03980 타임투타코(Time To Taco)
#   4%|▍         | 35/807 [00:30<10:58,  1.17it/s]
# [미발견] 03980 오까르베
#   5%|▍         | 37/807 [00:31<11:17,  1.14it/s]
# [미발견] 03989 노체
#   5%|▍         | 38/807 [00:32<10:46,  1.19it/s]
# [미발견] 03979 베홍리
#   5%|▌         | 41/807 [00:35<11:25,  1.12it/s]
# [미발견] 03982 김부자네
#   5%|▌         | 42/807 [00:36<10:24,  1.22it/s]
# [미발견] 03980 꽁블s(뻴르멜르)
#   6%|▌         | 45/807 [00:38<10:37,  1.19it/s]
# [미발견] 03979 녹녹
#   6%|▌         | 50/807 [00:42<11:24,  1.11it/s]
# [미발견] 03987 테이트하우스(TATE HOUSE)
#   6%|▋         | 51/807 [00:43<10:26,  1.21it/s]
# [미발견] 03984 티아이지디(TIGD)
#   6%|▋         | 52/807 [00:44<09:48,  1.28it/s]
# [미발견] 03987 유히(YUHI)
#   8%|▊         | 62/807 [00:53<12:24,  1.00it/s]
# [미발견] 03979 흰그루
#   8%|▊         | 67/807 [00:58<13:07,  1.06s/it]
# [미발견] 03980 셀로나(Celona)
#  10%|▉         | 77/807 [01:08<12:06,  1.01it/s]
# [미발견] 03984 파네트 에그타르트
#  11%|█▏        | 92/807 [01:23<12:36,  1.06s/it]
# [미발견] 03982 귀차니즘
#  14%|█▎        | 109/807 [01:41<13:01,  1.12s/it]
# [미발견] 03982 호랑이칡냉면(홍대직영점)
#  14%|█▎        | 110/807 [01:42<11:23,  1.02it/s]
# [미발견] 03980 (주)메종드연남
#  14%|█▍        | 111/807 [01:42<10:33,  1.10it/s]
# [미발견] 03974 뉴페이즈(new phase)
#  16%|█▌        | 127/807 [01:58<12:01,  1.06s/it]
# [미발견] 03984 연희기획
#  16%|█▋        | 133/807 [02:04<10:58,  1.02it/s]
# [미발견] 03980 뽁당 볶음밥 홍대연남점
#  17%|█▋        | 136/807 [02:06<10:48,  1.03it/s]
# [미발견] 03985 옐로우로즈
#  19%|█▉        | 153/807 [02:24<11:38,  1.07s/it]
# [미발견] 03982 수퍼소닉(Supersonic)
#  21%|██        | 167/807 [02:38<11:10,  1.05s/it]
# [미발견] 03974 유메이크쿠키
#  21%|██        | 171/807 [02:42<10:49,  1.02s/it]
# [미발견] 03982 포잇(Poit)
#  23%|██▎       | 183/807 [02:54<10:33,  1.02s/it]
# [미발견] 03982 삼이사 파스타(324 Pasta)
#  24%|██▍       | 195/807 [03:07<11:31,  1.13s/it]
# [미발견] 03982 베러위켄드(BETTER WEEKEND)
#  25%|██▍       | 199/807 [03:11<10:36,  1.05s/it]
# [미발견] 03980 뉴스 연남점
#  25%|██▌       | 202/807 [03:14<09:45,  1.03it/s]
# [미발견] 03991 새숯가
#  25%|██▌       | 204/807 [03:15<08:58,  1.12it/s]
# [미발견] 03982 다크사이드 연남
#  26%|██▋       | 213/807 [03:24<09:36,  1.03it/s]
# [미발견] 03987 모이다
#  28%|██▊       | 223/807 [03:33<09:45,  1.00s/it]
# [미발견] 03982 우라프라우드
#  29%|██▉       | 236/807 [03:46<09:49,  1.03s/it]
# [미발견] 03979 하뭇(HAMUT)
#  30%|██▉       | 240/807 [03:50<09:50,  1.04s/it]
# [미발견] 03982 야마타츠
#  33%|███▎      | 263/807 [04:14<09:32,  1.05s/it]
# [미발견] 03985 무채색 숲
#  36%|███▌      | 289/807 [04:41<09:11,  1.07s/it]
# [미발견] 03984 시부야타코야키
#  39%|███▊      | 311/807 [05:03<08:29,  1.03s/it]
# [미발견] 03982 긱스(GYCS)
#  42%|████▏     | 336/807 [05:29<07:36,  1.03it/s]
# [미발견] 03982 로컬코드(LOCALCODE)
#  44%|████▍     | 358/807 [05:51<07:58,  1.06s/it]
# [미발견] 03988 리스본 캔어리(LISBON CANNERY)
#  45%|████▌     | 365/807 [05:58<07:57,  1.08s/it]
# [미발견] 03982 풀업
#  46%|████▌     | 370/807 [06:03<07:26,  1.02s/it]
# [미발견] 03982 차차밀로(ChaChaMIllo)
#  48%|████▊     | 387/807 [06:20<07:14,  1.03s/it]
# [미발견] 03985 힉스(HIGGS)
#  49%|████▊     | 392/807 [06:25<07:18,  1.06s/it]
# [미발견] 03982 쿄카
#  57%|█████▋    | 461/807 [07:37<06:12,  1.08s/it]
# [미발견] 03982 퍼펙트데이즈(Perfect Days)
#  58%|█████▊    | 468/807 [07:43<05:35,  1.01it/s]
# [미발견] 03989 수퍼바켙(SUPER BARKET)
#  59%|█████▉    | 475/807 [07:51<05:45,  1.04s/it]
# [미발견] 03981 바르(varr)
#  60%|█████▉    | 482/807 [07:57<05:26,  1.00s/it]
# [미발견] 03986 고을집 김치생삼겸살
#  63%|██████▎   | 512/807 [08:29<05:02,  1.03s/it]
# [미발견] 03984 리옥
#  66%|██████▋   | 535/807 [08:52<04:43,  1.04s/it]
# [미발견] 03982 벤코크(vencoch)
#  68%|██████▊   | 547/807 [09:04<04:28,  1.03s/it]
# [미발견] 03979 베리굿베리카인드(Berry good Berry kind)
#  72%|███████▏  | 585/807 [09:42<03:41,  1.00it/s]
# [미발견] 03989 크루이프14(KRUIJFF14)
#  73%|███████▎  | 589/807 [09:46<03:38,  1.00s/it]
# [미발견] 03982 왼(when)
#  73%|███████▎  | 590/807 [09:46<03:15,  1.11it/s]
# [미발견] 03982 나는 술로
#  75%|███████▍  | 603/807 [10:00<03:39,  1.07s/it]
# [미발견] 03976 한성관
#  76%|███████▌  | 612/807 [10:09<03:21,  1.03s/it]
# [미발견] 03982 봉화
#  76%|███████▋  | 616/807 [10:13<03:13,  1.01s/it]
# [미발견] 03990 벌스투(VERSEⅡ)
#  79%|███████▉  | 641/807 [10:39<02:58,  1.08s/it]
# [미발견] 03982 카우치 포테이토(COUCH POTATO)
#  80%|███████▉  | 643/807 [10:41<02:59,  1.09s/it]
# [미발견] 03982 플레이 아레나
#  82%|████████▏ | 662/807 [11:01<02:41,  1.11s/it]
# [미발견] 03990 하루노유키(はるのゆき)
#  82%|████████▏ | 665/807 [11:03<02:22,  1.01s/it]
# [미발견] 03980 더빌리랩스(The Billi Labs)
#  83%|████████▎ | 672/807 [11:11<02:31,  1.13s/it]
# [미발견] 03980 잇-다
#  84%|████████▍ | 681/807 [11:20<02:16,  1.08s/it]
# [미발견] 03980 그래스호퍼(GRASSHOPPER)
#  86%|████████▋ | 697/807 [11:36<01:50,  1.01s/it]
# [미발견] 03982 소주방 2호점
#  87%|████████▋ | 706/807 [11:45<01:42,  1.02s/it]
# [미발견] 03982 부페트발라(Buffet Bala)
#  89%|████████▉ | 718/807 [11:57<01:31,  1.03s/it]
# [미발견] 03990 오이도(52nd Street)
#  92%|█████████▏| 744/807 [12:24<01:08,  1.08s/it]
# [미발견] 03990 곰셰프네
#  93%|█████████▎| 753/807 [12:33<00:56,  1.04s/it]
# [미발견] 03989 밥스바비연남점
#  94%|█████████▍| 761/807 [12:42<00:49,  1.07s/it]
# [미발견] 03982 스위트가든 뽀아르(sweetgarden poire)
#  95%|█████████▍| 764/807 [12:44<00:42,  1.01it/s]
# [미발견] 03986 문부터
#  96%|█████████▋| 778/807 [12:59<00:31,  1.08s/it]
# [미발견] 03986 장강
#  97%|█████████▋| 786/807 [13:08<00:22,  1.06s/it]
# [미발견] 03981 한스뮤직챔버
#  98%|█████████▊| 788/807 [13:09<00:18,  1.03it/s]
# [미발견] 03974 만경식당
#  98%|█████████▊| 792/807 [13:13<00:15,  1.03s/it]
# [미발견] 03987 김밥세상
# 100%|██████████| 807/807 [13:29<00:00,  1.00s/it]
# 리뷰 수집 완료 및 저장 완료

# %%
df_yeonnam_reviews_gmaps = pd.read_csv("C:/medici_class/00.프로젝트/최종프로젝트 임시파일/yeonnam_restaurant_reviews_googlemaps.csv", encoding='cp949')
df_yeonnam_reviews_gmaps
# Out:
#       별점                                               리뷰내용          작성자  \
# 0      5                           대박 사르르 녹는 뚱카롱 짱맛 꿀맛이에용ㅠㅠ    JiWon Kim
# 1      5                                                NaN           두리
# 2      5  히레와 로스 카츠 정식 점심으로 먹었는데 제주 흑돼지 사용과 말돈소금 및 비법 드레...          우동희
# 3      5  남자친구랑 홍대에서 돈카츠맛집을 찾았습니다!!!\r\n분위기도 너무 좋아서 나중에 ...          박지현
# 4      4  밥이 솥밥으로 나온다는게 매력적임. 돈까스는 두툼하고 지방이 적당하게 있어서 맛있었...         투어리즘
# ...   ..                                                ...          ...
# 2796   3  요즘엔 인스타에서 뜨는 광고를 통해 신상 가게 정보를 얻는 좋은 예도 있지만 여기저...  ethan ghymn
# 2797   5  연트럴파크 맛집 뭉텅 연남점을 찾았습니다. 연남동 고기집 뭉텅은 홍대입구역 3번 출...         호빵공장
# 2798   5  본점보다맛있어요! 뭉텅여기서 처음가고 너무맛있어서 본점갔는데 연남점이 훨씬고기가 큰...  Junwon Choi
# 2799   5  오랜만에 맛있는고기집 찾았어요 고기찾아먹진않는타입인데 가끔땡길때 있잖아유?\r\n사...         하릴없이
# 2800   5  우리는 토요일에 자리에 앉기 전에 잠시 기다렸습니다. 나는 그들의 혼합 접시가 최고...  Warren Wigh
#
#                                              작성자 프로필 링크     시간      사업장명  \
# 0     https://www.google.com/maps/contrib/1055269768...   6년 전       사르르
# 1     https://www.google.com/maps/contrib/1122504793...   4년 전       사르르
# 2     https://www.google.com/maps/contrib/1048404036...   4달 전       돈토키
# 3     https://www.google.com/maps/contrib/1130968599...   6달 전       돈토키
# 4     https://www.google.com/maps/contrib/1093313547...   2년 전       돈토키
# ...                                                 ...    ...       ...
# 2796  https://www.google.com/maps/contrib/1042004016...   3년 전  항저우 샤롱바오
# 2797  https://www.google.com/maps/contrib/1023673874...  10달 전    뭉텅 연남점
# 2798  https://www.google.com/maps/contrib/1131549655...   7달 전    뭉텅 연남점
# 2799  https://www.google.com/maps/contrib/1162235992...   1년 전    뭉텅 연남점
# 2800  https://www.google.com/maps/contrib/1115960572...   6달 전    뭉텅 연남점
#
#      검색결과 가게명
# 0      사르르과자점
# 1      사르르과자점
# 2        카마카츠
# 3        카마카츠
# 4        카마카츠
# ...       ...
# 2796    샤오롱바오
# 2797   뭉텅 연남점
# 2798   뭉텅 연남점
# 2799   뭉텅 연남점
# 2800   뭉텅 연남점
#
# [2801 rows x 7 columns]

# %%
df_yeonnam_reviews_gmaps.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2801 entries, 0 to 2800
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   별점          2801 non-null   int64
#  1   리뷰내용        2704 non-null   object
#  2   작성자         2801 non-null   object
#  3   작성자 프로필 링크  2801 non-null   object
#  4   시간          2801 non-null   object
#  5   사업장명        2801 non-null   object
#  6   검색결과 가게명    2801 non-null   object
# dtypes: int64(1), object(6)
# memory usage: 153.3+ KB

# %%
df_yeonnam_reviews_gmaps['사업장명'].value_counts()
# Out:
# 사업장명
# 시실리             10
# 향미              10
# 리틀파파포           10
# 고스트블랙 연남점       10
# 해피치즈스마일 연남점      5
#                 ..
# 소코               1
# 마스타 하이볼 연남점      1
# 굽네치킨 연남점         1
# 플루밍(Pluming)     1
# 제일 연남            1
# Name: count, Length: 633, dtype: int64

# %%
df_yeonnam_reviews_gmaps['사업장명'].nunique()
# Out:
# 633

# %%
from difflib import SequenceMatcher

def get_similarity(a, b):
    return SequenceMatcher(None, str(a), str(b)).ratio()  # 0~1 사이 유사도 반환

# 새로운 열 '이름_유사도' 추가
df_yeonnam_reviews_gmaps['검색결과와 사업장명 유사도'] = df_yeonnam_reviews_gmaps.apply(lambda row: get_similarity(row['사업장명'], row['검색결과 가게명']), axis=1)
df_yeonnam_reviews_gmaps
# Out:
#       별점                                               리뷰내용          작성자  \
# 0      5                           대박 사르르 녹는 뚱카롱 짱맛 꿀맛이에용ㅠㅠ    JiWon Kim
# 1      5                                                NaN           두리
# 2      5  히레와 로스 카츠 정식 점심으로 먹었는데 제주 흑돼지 사용과 말돈소금 및 비법 드레...          우동희
# 3      5  남자친구랑 홍대에서 돈카츠맛집을 찾았습니다!!!\r\n분위기도 너무 좋아서 나중에 ...          박지현
# 4      4  밥이 솥밥으로 나온다는게 매력적임. 돈까스는 두툼하고 지방이 적당하게 있어서 맛있었...         투어리즘
# ...   ..                                                ...          ...
# 2796   3  요즘엔 인스타에서 뜨는 광고를 통해 신상 가게 정보를 얻는 좋은 예도 있지만 여기저...  ethan ghymn
# 2797   5  연트럴파크 맛집 뭉텅 연남점을 찾았습니다. 연남동 고기집 뭉텅은 홍대입구역 3번 출...         호빵공장
# 2798   5  본점보다맛있어요! 뭉텅여기서 처음가고 너무맛있어서 본점갔는데 연남점이 훨씬고기가 큰...  Junwon Choi
# 2799   5  오랜만에 맛있는고기집 찾았어요 고기찾아먹진않는타입인데 가끔땡길때 있잖아유?\r\n사...         하릴없이
# 2800   5  우리는 토요일에 자리에 앉기 전에 잠시 기다렸습니다. 나는 그들의 혼합 접시가 최고...  Warren Wigh
#
#                                              작성자 프로필 링크     시간      사업장명  \
# 0     https://www.google.com/maps/contrib/1055269768...   6년 전       사르르
# 1     https://www.google.com/maps/contrib/1122504793...   4년 전       사르르
# 2     https://www.google.com/maps/contrib/1048404036...   4달 전       돈토키
# 3     https://www.google.com/maps/contrib/1130968599...   6달 전       돈토키
# 4     https://www.google.com/maps/contrib/1093313547...   2년 전       돈토키
# ...                                                 ...    ...       ...
# 2796  https://www.google.com/maps/contrib/1042004016...   3년 전  항저우 샤롱바오
# 2797  https://www.google.com/maps/contrib/1023673874...  10달 전    뭉텅 연남점
# 2798  https://www.google.com/maps/contrib/1131549655...   7달 전    뭉텅 연남점
# 2799  https://www.google.com/maps/contrib/1162235992...   1년 전    뭉텅 연남점
# 2800  https://www.google.com/maps/contrib/1115960572...   6달 전    뭉텅 연남점
#
#      검색결과 가게명  검색결과와 사업장명 유사도
# 0      사르르과자점        0.666667
# 1      사르르과자점        0.666667
# 2        카마카츠        0.000000
# 3        카마카츠        0.000000
# 4        카마카츠        0.000000
# ...       ...             ...
# 2796    샤오롱바오        0.615385
# 2797   뭉텅 연남점        1.000000
# 2798   뭉텅 연남점        1.000000
# 2799   뭉텅 연남점        1.000000
# 2800   뭉텅 연남점        1.000000
#
# [2801 rows x 8 columns]

# %%
df_yeonnam_reviews_gmaps.to_csv("gmaps_reviews.csv", index=False, encoding="utf-8-sig")
print("리뷰 수집 완료 및 저장 완료")
# Out:
# 리뷰 수집 완료 및 저장 완료

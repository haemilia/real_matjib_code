# %%
import duckdb
from pathlib import Path
import pandas as pd

# %% [markdown]
# # 네이버 데이터 DB로 옮기기

# %%
# 네이버 데이터 파일 위치
datafiles_dir = Path("G:/My Drive/Data/naver_search_results")
restaurants_path = datafiles_dir / "restaurants_table.parquet"
navermap_reviews_path = datafiles_dir / "navermap_reviews.parquet"
naverblog_reviews_path = datafiles_dir / "naverblog_reviews_store_id.parquet" # store_id 추가 버전
navermap_reviews_labelled_path = datafiles_dir / "navermap_reviews_labelled.parquet" # 라벨링을 위해 샘플링한 애들만 모아둔 파일. 완전한 라벨링은 안 된 상태 but 라벨링 된 애들만 가지고 모델 훈련 중...

# %%
# 새로운 DB 파일 위치 (G 드라이브, H 드라이브 등 어디에 있는 지 확인해주세요)
new_db_path = Path(r"H:\My Drive") / "reviews.db"

# %%
with duckdb.connect(database=new_db_path, read_only=False) as db_conn:
    q1 = f"CREATE OR REPLACE TABLE naver_restaurants AS SELECT * FROM '{restaurants_path.as_posix()}'"
    db_conn.execute(q1)
    q2 = f"CREATE OR REPLACE TABLE navermap_reviews AS SELECT * FROM '{navermap_reviews_path.as_posix()}'"
    db_conn.execute(q2)
    q3 = f"CREATE OR REPLACE TABLE naverblog_reviews AS SELECT * FROM '{naverblog_reviews_path.as_posix()}'"
    db_conn.execute(q3)
    q4 = f"CREATE OR REPLACE TABLE navermap_reviews_labelled AS SELECT * FROM '{navermap_reviews_labelled_path.as_posix()}'"
    db_conn.execute(q4)

# %%
local_db_path = Path(r"C:\Users\m\2025\project\code_only\real_matjib_code\reviews_local.db")
with duckdb.connect(database=local_db_path, read_only=False) as db_conn:
    q1 = f"CREATE OR REPLACE TABLE naver_restaurants AS SELECT * FROM '{restaurants_path.as_posix()}'"
    db_conn.execute(q1)
    q2 = f"CREATE OR REPLACE TABLE navermap_reviews AS SELECT * FROM '{navermap_reviews_path.as_posix()}'"
    db_conn.execute(q2)
    q3 = f"CREATE OR REPLACE TABLE naverblog_reviews AS SELECT * FROM '{naverblog_reviews_path.as_posix()}'"
    db_conn.execute(q3)

# %%
local_db_path = Path(r"C:\Users\m\2025\project\code_only\real_matjib_code\reviews_local.db")
with duckdb.connect(database=local_db_path) as conn:
    df = conn.table("navermap_reviews").fetchdf()
    display(df.T)
# Out:
#                                                                   0       \
# review_id                                       6828df8fb0df3c4081c31b51
# store_id                                                      2038175452
# store_naver_name                                          서울혼술바 제주아홉 홍대점
# store_name                                                서울혼술바 제주아홉 홍대점
# store_reply                                                         None
# review_text            최근간 혼술바 중에 진짜 베스트였어요\n술 종류도 다양했고 술찌인 저도 먹을 수 있...
# num_of_media                                                          10
# image_links            [https://pup-review-phinf.pstatic.net/MjAyNTA1...
# video_thumbnail_links                                               <NA>
# visit_count                                                            1
# author_nickname                                                    미농쓰S2
# author_total_reviews                                                 9.0
# author_total_images                                                 26.0
# reactions_fun                                                        0.0
# reactions_helpful                                                    0.0
# reactions_wannago                                                    0.0
# reactions_cool                                                       0.0
# review_datetime                                      2025-05-17 19:04:53
# review_year                                                         2025
# visit_keywords                                 [예약 없이 이용, 바로 입장, 친목, 친구]
# purchase_item                                                       파우스트
# rating                                                               NaN
# keyword_tags_code      [alcohol_var, drink_good, talk_good, atmospher...
# keyword_tags_hangul    [술이 다양해요, 음료가 맛있어요, 대화하기 좋아요, 차분한 분위기에요, 컨셉이 독...
# __index_level_0__                                                      0
#
#                                                                   1       \
# review_id                                       6826330c4ac4114f974f8e2e
# store_id                                                      2038175452
# store_naver_name                                          서울혼술바 제주아홉 홍대점
# store_name                                                서울혼술바 제주아홉 홍대점
# store_reply                                                         None
# review_text            혼자 왔는데 사장님 분들이 다 친절하셔서 마감까지 재밌게 놀고 가요~! 시그니처 칵...
# num_of_media                                                           3
# image_links            [https://pup-review-phinf.pstatic.net/MjAyNTA1...
# video_thumbnail_links                                               <NA>
# visit_count                                                            1
# author_nickname                                                  mnz****
# author_total_reviews                                                18.0
# author_total_images                                                 24.0
# reactions_fun                                                        0.0
# reactions_helpful                                                    0.0
# reactions_wannago                                                    0.0
# reactions_cool                                                       0.0
# review_datetime                                      2025-05-15 18:26:42
# review_year                                                         2025
# visit_keywords                                 [예약 없이 이용, 바로 입장, 일상, 혼자]
# purchase_item                                                       블랙아홉
# rating                                                               NaN
# keyword_tags_code      [talk_good, food_good, alcohol_var, special_me...
# keyword_tags_hangul     [대화하기 좋아요, 음식이 맛있어요, 술이 다양해요, 특별한 메뉴가 있어요, 친절해요]
# __index_level_0__                                                      1
#
#                                                                   2       \
# review_id                                       6828ea26e020e7520abbef29
# store_id                                                      2038175452
# store_naver_name                                          서울혼술바 제주아홉 홍대점
# store_name                                                서울혼술바 제주아홉 홍대점
# store_reply                                                         None
# review_text            난생 처음가본 혼술바 홍대는 항상 친구들 이랑만 놀러 가는 장소였는데 이렇게 편하고...
# num_of_media                                                           1
# image_links            [https://pup-review-phinf.pstatic.net/MjAyNTA1...
# video_thumbnail_links                                               <NA>
# visit_count                                                            1
# author_nickname                                               choisg1219
# author_total_reviews                                                 4.0
# author_total_images                                                  5.0
# reactions_fun                                                        0.0
# reactions_helpful                                                    0.0
# reactions_wannago                                                    0.0
# reactions_cool                                                       0.0
# review_datetime                                      2025-05-16 15:27:39
# review_year                                                         2025
# visit_keywords                                     [예약 없이 이용, 바로 입장, 혼자]
# purchase_item                                                    말리부 하이볼
# rating                                                               NaN
# keyword_tags_code      [alcohol_var, interior_cool, music_good, talk_...
# keyword_tags_hangul        [술이 다양해요, 인테리어가 멋져요, 음악이 좋아요, 대화하기 좋아요, 친절해요]
# __index_level_0__                                                      2
#
#                                                                   3       \
# review_id                                       6828d369ba6d7b7c9d7b3cab
# store_id                                                      2038175452
# store_naver_name                                          서울혼술바 제주아홉 홍대점
# store_name                                                서울혼술바 제주아홉 홍대점
# store_reply                                                         None
# review_text                            사람들이랑 소소한 대화 나누기도 좋고\n칵테일도 맛있어요🫶🏻
# num_of_media                                                           1
# image_links            [https://pup-review-phinf.pstatic.net/MjAyNTA1...
# video_thumbnail_links                                               <NA>
# visit_count                                                            1
# author_nickname                                                      김 융
# author_total_reviews                                                26.0
# author_total_images                                                 51.0
# reactions_fun                                                        0.0
# reactions_helpful                                                    0.0
# reactions_wannago                                                    0.0
# reactions_cool                                                       0.0
# review_datetime                                      2025-05-17 16:36:59
# review_year                                                         2025
# visit_keywords                                 [예약 없이 이용, 바로 입장, 친목, 친구]
# purchase_item                                                   얼그레이 하이볼
# rating                                                               NaN
# keyword_tags_code      [interior_cool, talk_good, drink_alone, alcoho...
# keyword_tags_hangul    [인테리어가 멋져요, 대화하기 좋아요, 혼술하기 좋아요, 술이 다양해요, 특별한 메...
# __index_level_0__                                                      3
#
#                                                                   4       \
# review_id                                       6829f068abbd149b84e655e4
# store_id                                                      2038175452
# store_naver_name                                          서울혼술바 제주아홉 홍대점
# store_name                                                서울혼술바 제주아홉 홍대점
# store_reply                                                         None
# review_text            제주도에서도 가봤는데 너무 좋아서 홍대점도 가보니 역시나 좋네요ㅠ !! \n혼술바 ...
# num_of_media                                                           1
# image_links            [https://pup-review-phinf.pstatic.net/MjAyNTA1...
# video_thumbnail_links                                               <NA>
# visit_count                                                            1
# author_nickname                                                    우채연96
# author_total_reviews                                                14.0
# author_total_images                                                  3.0
# reactions_fun                                                        0.0
# reactions_helpful                                                    0.0
# reactions_wannago                                                    0.0
# reactions_cool                                                       0.0
# review_datetime                                      2025-05-18 14:14:54
# review_year                                                         2025
# visit_keywords                                 [예약 없이 이용, 바로 입장, 친목, 친구]
# purchase_item                                                     피치 하이볼
# rating                                                               NaN
# keyword_tags_code      [interior_cool, talk_good, drink_alone, snack_...
# keyword_tags_hangul    [인테리어가 멋져요, 대화하기 좋아요, 혼술하기 좋아요, 기본 안주가 좋아요, 술이...
# __index_level_0__                                                      4
#
#                                                                   5       \
# review_id                                       6828933892365eaf5831cf31
# store_id                                                      2038175452
# store_naver_name                                          서울혼술바 제주아홉 홍대점
# store_name                                                서울혼술바 제주아홉 홍대점
# store_reply                                                         None
# review_text            가오픈에 미리 와봤는데 혼자 와도 친구랑 와도 편하게 어울릴 수 있는 분위기인 혼술...
# num_of_media                                                           0
# image_links                                                         <NA>
# video_thumbnail_links                                               <NA>
# visit_count                                                            1
# author_nickname                                              스파이더맨할래토르할래
# author_total_reviews                                                13.0
# author_total_images                                                 22.0
# reactions_fun                                                        0.0
# reactions_helpful                                                    0.0
# reactions_wannago                                                    0.0
# reactions_cool                                                       0.0
# review_datetime                                      2025-05-16 15:27:39
# review_year                                                         2025
# visit_keywords                                 [예약 없이 이용, 바로 입장, 일상, 친구]
# purchase_item                                                    말리부 하이볼
# rating                                                               NaN
# keyword_tags_code      [interior_cool, drink_alone, spacious, alcohol...
# keyword_tags_hangul    [인테리어가 멋져요, 혼술하기 좋아요, 매장이 넓어요, 술이 다양해요, 특별한 메뉴...
# __index_level_0__                                                      5
#
#                                                                   6       \
# review_id                                       682b30905943d86b8318fdbc
# store_id                                                      2038175452
# store_naver_name                                          서울혼술바 제주아홉 홍대점
# store_name                                                서울혼술바 제주아홉 홍대점
# store_reply                                                         None
# review_text                                 혼술하러 왔다가 친구 사귀고 가요\n너무 재밌어요!
# num_of_media                                                           1
# image_links            [https://pup-review-phinf.pstatic.net/MjAyNTA1...
# video_thumbnail_links                                               <NA>
# visit_count                                                            1
# author_nickname                                                  dol****
# author_total_reviews                                                11.0
# author_total_images                                                  5.0
# reactions_fun                                                        0.0
# reactions_helpful                                                    0.0
# reactions_wannago                                                    0.0
# reactions_cool                                                       0.0
# review_datetime                                      2025-05-19 13:19:49
# review_year                                                         2025
# visit_keywords                                 [예약 없이 이용, 바로 입장, 친목, 친구]
# purchase_item                                                        갓파더
# rating                                                               NaN
# keyword_tags_code      [food_good, alcohol_var, special_menu, interio...
# keyword_tags_hangul    [음식이 맛있어요, 술이 다양해요, 특별한 메뉴가 있어요, 인테리어가 멋져요, 혼술...
# __index_level_0__                                                      6
#
#                                                                   7       \
# review_id                                       68262db5227d3640fb09b669
# store_id                                                      2038175452
# store_naver_name                                          서울혼술바 제주아홉 홍대점
# store_name                                                서울혼술바 제주아홉 홍대점
# store_reply                                                         None
# review_text            서귀포에서 방문했던 기억이 너무 좋아서, 이번에 홍대에 오픈했다길래 방문했습니다! ...
# num_of_media                                                           0
# image_links                                                         <NA>
# video_thumbnail_links                                               <NA>
# visit_count                                                            1
# author_nickname                                                 rla63446
# author_total_reviews                                                21.0
# author_total_images                                                  4.0
# reactions_fun                                                        0.0
# reactions_helpful                                                    0.0
# reactions_wannago                                                    0.0
# reactions_cool                                                       0.0
# review_datetime                                      2025-05-15 14:27:35
# review_year                                                         2025
# visit_keywords                                [예약 없이 이용, 바로 입장, 나들이, 혼자]
# purchase_item                                                   얼그레이 하이볼
# rating                                                               NaN
# keyword_tags_code      [alcohol_var, interior_cool, music_good, talk_...
# keyword_tags_hangul    [술이 다양해요, 인테리어가 멋져요, 음악이 좋아요, 대화하기 좋아요, 혼술하기 좋아요]
# __index_level_0__                                                      7
#
#                                                                   8       \
# review_id                                       682a91ffd18f04a3581c6416
# store_id                                                      2038175452
# store_naver_name                                          서울혼술바 제주아홉 홍대점
# store_name                                                서울혼술바 제주아홉 홍대점
# store_reply                                                         None
# review_text            첫번째 방문이 되게 좋은 기억이었어서 재방문 했습니다! 가볍게 술 한 잔 하고 대화...
# num_of_media                                                           0
# image_links                                                         <NA>
# video_thumbnail_links                                               <NA>
# visit_count                                                            2
# author_nickname                                                 rla63446
# author_total_reviews                                                21.0
# author_total_images                                                  4.0
# reactions_fun                                                        0.0
# reactions_helpful                                                    0.0
# reactions_wannago                                                    0.0
# reactions_cool                                                       0.0
# review_datetime                                      2025-05-17 14:03:47
# review_year                                                         2025
# visit_keywords                                [예약 없이 이용, 바로 입장, 나들이, 혼자]
# purchase_item                                                   얼그레이 하이볼
# rating                                                               NaN
# keyword_tags_code      [alcohol_var, special_menu, music_good, talk_g...
# keyword_tags_hangul    [술이 다양해요, 특별한 메뉴가 있어요, 음악이 좋아요, 대화하기 좋아요, 혼술하기...
# __index_level_0__                                                      8
#
#                                                                   9       ...  \
# review_id                                       682926a2c724fdea0112f11c  ...
# store_id                                                      2038175452  ...
# store_naver_name                                          서울혼술바 제주아홉 홍대점  ...
# store_name                                                서울혼술바 제주아홉 홍대점  ...
# store_reply                                                         None  ...
# review_text            사장님 너무 친절하시고 분위기,인테리어도 취향이라 기분좋게 마셨습니다!☺️\n또 방...  ...
# num_of_media                                                           0  ...
# image_links                                                         <NA>  ...
# video_thumbnail_links                                               <NA>  ...
# visit_count                                                            1  ...
# author_nickname                                                     비람70  ...
# author_total_reviews                                                16.0  ...
# author_total_images                                                  3.0  ...
# reactions_fun                                                        0.0  ...
# reactions_helpful                                                    0.0  ...
# reactions_wannago                                                    0.0  ...
# reactions_cool                                                       0.0  ...
# review_datetime                                      2025-05-17 17:48:45  ...
# review_year                                                         2025  ...
# visit_keywords                                 [예약 없이 이용, 바로 입장, 친목, 친구]  ...
# purchase_item                                                      제주모히또  ...
# rating                                                               NaN  ...
# keyword_tags_code                       [food_good, interior_cool, kind]  ...
# keyword_tags_hangul                          [음식이 맛있어요, 인테리어가 멋져요, 친절해요]  ...
# __index_level_0__                                                      9  ...
#
#                                                                   293592  \
# review_id                                       5e849adbf483b900128b3739
# store_id                                                        31036949
# store_naver_name                                                   코리아식당
# store_name                                                           코리아
# store_reply                                                         None
# review_text                                             #연남동 #괜찮음 #약간비싼편
# num_of_media                                                           1
# image_links            [https://pup-review-phinf.pstatic.net/MjAyMzEw...
# video_thumbnail_links                                               <NA>
# visit_count                                                            1
# author_nickname                                                      망유랑
# author_total_reviews                                               579.0
# author_total_images                                                360.0
# reactions_fun                                                        0.0
# reactions_helpful                                                    0.0
# reactions_wannago                                                    0.0
# reactions_cool                                                       0.0
# review_datetime                                      2020-04-01 10:18:00
# review_year                                                         2020
# visit_keywords                                                      <NA>
# purchase_item                                                      가자미구이
# rating                                                               3.0
# keyword_tags_code                                                   <NA>
# keyword_tags_hangul                                                 <NA>
# __index_level_0__                                                 293593
#
#                                          293593  \
# review_id              5ecafe13d10a530011a1b211
# store_id                               31036949
# store_naver_name                          코리아식당
# store_name                                  코리아
# store_reply                                None
# review_text                        집밥 먹고싶을때 가는곳
# num_of_media                                  0
# image_links                                <NA>
# video_thumbnail_links                      <NA>
# visit_count                                   1
# author_nickname                         tnd****
# author_total_reviews                      415.0
# author_total_images                        79.0
# reactions_fun                               0.0
# reactions_helpful                           0.0
# reactions_wannago                           0.0
# reactions_cool                              0.0
# review_datetime             2020-05-23 08:46:00
# review_year                                2020
# visit_keywords                             <NA>
# purchase_item                              None
# rating                                      5.0
# keyword_tags_code                          <NA>
# keyword_tags_hangul                        <NA>
# __index_level_0__                        293594
#
#                                                                   293594  \
# review_id                                       5eea9a3c97208500105f7f32
# store_id                                                        31036949
# store_naver_name                                                   코리아식당
# store_name                                                           코리아
# store_reply                                                         None
# review_text                                                         맛있어요
# num_of_media                                                           1
# image_links            [https://pup-review-phinf.pstatic.net/MjAyMzEw...
# video_thumbnail_links                                               <NA>
# visit_count                                                            1
# author_nickname                                                      다빔잉
# author_total_reviews                                               318.0
# author_total_images                                                200.0
# reactions_fun                                                        0.0
# reactions_helpful                                                    1.0
# reactions_wannago                                                    0.0
# reactions_cool                                                       0.0
# review_datetime                                      2020-06-16 09:09:00
# review_year                                                         2020
# visit_keywords                                                      <NA>
# purchase_item                                                       None
# rating                                                               5.0
# keyword_tags_code                                                   <NA>
# keyword_tags_hangul                                                 <NA>
# __index_level_0__                                                 293595
#
#                                          293595                    293596  \
# review_id              5f185aa5c973e70010399cf8  5f13eb2391480900106f83e4
# store_id                               31036949                  31036949
# store_naver_name                          코리아식당                     코리아식당
# store_name                                  코리아                       코리아
# store_reply                                None                      None
# review_text                                 맛나요                        맛남
# num_of_media                                  0                         0
# image_links                                <NA>                      <NA>
# video_thumbnail_links                      <NA>                      <NA>
# visit_count                                   2                         1
# author_nickname                         mel****                   mel****
# author_total_reviews                      211.0                     211.0
# author_total_images                        16.0                      16.0
# reactions_fun                               0.0                       0.0
# reactions_helpful                           0.0                       0.0
# reactions_wannago                           0.0                       0.0
# reactions_cool                              0.0                       0.0
# review_datetime             2020-07-22 06:43:00       2020-07-18 09:12:00
# review_year                                2020                      2020
# visit_keywords                             <NA>                      <NA>
# purchase_item                              None                      None
# rating                                      5.0                       5.0
# keyword_tags_code                          <NA>                      <NA>
# keyword_tags_hangul                        <NA>                      <NA>
# __index_level_0__                        293596                    293597
#
#                                                    293597  \
# review_id                        5e548a92dc00d40011cb040b
# store_id                                         31036949
# store_naver_name                                    코리아식당
# store_name                                            코리아
# store_reply                                          None
# review_text            이 맛에 이 가격 어쩔겁니까!\n집근처면 매일 가고싶네요*ㅁ*
# num_of_media                                            0
# image_links                                          <NA>
# video_thumbnail_links                                <NA>
# visit_count                                             1
# author_nickname                                        옴쓰
# author_total_reviews                                473.0
# author_total_images                                   9.0
# reactions_fun                                         0.0
# reactions_helpful                                     0.0
# reactions_wannago                                     0.0
# reactions_cool                                        0.0
# review_datetime                       2020-02-25 02:33:00
# review_year                                          2020
# visit_keywords                                       <NA>
# purchase_item                                        None
# rating                                                5.0
# keyword_tags_code                                    <NA>
# keyword_tags_hangul                                  <NA>
# __index_level_0__                                  293598
#
#                                             293598                    293599  \
# review_id                 5e548a5521943f0011d37227  5eb96e4da437330010937e6a
# store_id                                  31036949                  31036949
# store_naver_name                             코리아식당                     코리아식당
# store_name                                     코리아                       코리아
# store_reply                                   None                      None
# review_text            코리아식당 상호명이랑 딱맞아요 한국대표 가정식임                  비지찌게 최애메뉴
# num_of_media                                     0                         0
# image_links                                   <NA>                      <NA>
# video_thumbnail_links                         <NA>                      <NA>
# visit_count                                      1                         1
# author_nickname                              져니비손스                  포차코키티흰둥이
# author_total_reviews                         117.0                     419.0
# author_total_images                           32.0                       7.0
# reactions_fun                                  0.0                       0.0
# reactions_helpful                              0.0                       0.0
# reactions_wannago                              0.0                       0.0
# reactions_cool                                 0.0                       0.0
# review_datetime                2020-02-25 02:33:00       2020-02-28 12:22:00
# review_year                                   2020                      2020
# visit_keywords                                <NA>                      <NA>
# purchase_item                                 None                      None
# rating                                         5.0                       4.5
# keyword_tags_code                             <NA>                      <NA>
# keyword_tags_hangul                           <NA>                      <NA>
# __index_level_0__                           293599                    293600
#
#                                          293600                    293601
# review_id              5e60b0802c4d1600113c118e  5e54ed074309c300112bbfad
# store_id                               31036949                  31036949
# store_naver_name                          코리아식당                     코리아식당
# store_name                                  코리아                       코리아
# store_reply                                None                      None
# review_text                              곱창전골 굿                  진정한 맛집!!
# num_of_media                                  0                         0
# image_links                                <NA>                      <NA>
# video_thumbnail_links                      <NA>                      <NA>
# visit_count                                   1                         1
# author_nickname                            명교80                      테스터기
# author_total_reviews                      174.0                     241.0
# author_total_images                         3.0                       4.0
# reactions_fun                               0.0                       0.0
# reactions_helpful                           0.0                       0.0
# reactions_wannago                           0.0                       0.0
# reactions_cool                              0.0                       0.0
# review_datetime             2020-03-05 07:55:00       2020-02-25 02:33:00
# review_year                                2020                      2020
# visit_keywords                             <NA>                      <NA>
# purchase_item                              None                      None
# rating                                      5.0                       5.0
# keyword_tags_code                          <NA>                      <NA>
# keyword_tags_hangul                        <NA>                      <NA>
# __index_level_0__                        293601                    293602
#
# [25 rows x 293602 columns]

# %% [markdown]
# # DB에서 정보 보기

# %%
with duckdb.connect(database=new_db_path, read_only=False) as db_conn:
    # DB에 어떤 테이블 있는 지 보기
    db_conn.sql("PRAGMA show_tables_expanded;").show() 
    # 데이터프레임으로 테이블 가져오기
    restaurants = db_conn.table("restaurants").to_df() 
    display(restaurants)

# %%
with duckdb.connect(database=new_db_path, read_only=True) as db_conn:
    blog = db_conn.table("navermap_reviews").to_df() 
    display(blog.T)

# %%
blog["post_url"].is_unique
